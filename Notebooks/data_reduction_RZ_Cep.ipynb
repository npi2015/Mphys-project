# %%
from pathlib import Path

from matplotlib import pyplot as plt
import numpy as np

from astropy import units as u
import ccdproc as ccdp

from convenience_functions import show_image

filter = 'Green'

# %%
def find_nearest_dark_exposure(image, dark_exposure_times, tolerance=0.5):
    """
    Find the nearest exposure time of a dark frame to the exposure time of the image,
    raising an error if the difference in exposure time is more than tolerance.

    Parameters
    ----------

    image : astropy.nddata.CCDData
        Image for which a matching dark is needed.

    dark_exposure_times : list
        Exposure times for which there are darks.

    tolerance : float or ``None``, optional
        Maximum difference, in seconds, between the image and the closest dark. Set
        to ``None`` to skip the tolerance test.

    Returns
    -------

    float
        Closest dark exposure time to the image.
    """

    dark_exposures = np.array(list(dark_exposure_times))
    idx = np.argmin(np.abs(dark_exposures - image.header['exptime']))
    closest_dark_exposure = dark_exposures[idx]

    if (tolerance is not None and
            np.abs(image.header['exptime'] - closest_dark_exposure) > tolerance):

        raise RuntimeError('Closest dark exposure time is {} for flat of exposure '
                           'time {}.'.format(closest_dark_exposure, image.header['exptime']))


    return closest_dark_exposure

# %% [markdown]
# ## 2022/03/20

# %%
# Use custom style for larger fonts and figures
plt.style.use('guide.mplstyle')

# %%
science_images_path = Path('..', '2022_12_07b', 'RZ_Cep', 'star', 'Light', filter)
dark_images_path = Path('..', 'darks-reduced-6-12-RzCep')
flats_path = Path('..', 'reduced-flats-6-12', filter)

master_darks = ccdp.ImageFileCollection(dark_images_path)
master_flats = ccdp.ImageFileCollection(flats_path)
science_raw = ccdp.ImageFileCollection(science_images_path)

# %%
science_image_type = 'Light Frame'

combined_darks = {ccd.header['exptime']: ccd for ccd in master_darks.ccds(imagetyp='Dark Frame', combined=True)}
combined_flats = {ccd.header['filter']: ccd for ccd in master_flats.ccds(imagetyp='Flat Frame', combined=True)}
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.873247 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.873247 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870342 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870342 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.575010 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.575010 from DATE-OBS'.

# %%
destination_path = Path('..','reduced-lights_2022_12_06', filter)
destination_path.mkdir( exist_ok = True)

# %%
all_reds = []
light_ccds = []
for light, file_name in science_raw.ccds(imagetyp=science_image_type, return_fname=True, ccd_kwargs=dict(unit='adu')):
    light_ccds.append(light)

    closest_dark = find_nearest_dark_exposure(light, combined_darks.keys())
    reduced = ccdp.subtract_dark(light, combined_darks[closest_dark],
                                 exposure_time='exptime', exposure_unit=u.second
                                 )
    good_flat = combined_flats[reduced.header['filter']]
    reduced = ccdp.flat_correct(reduced, good_flat)
    all_reds.append(reduced)
    reduced.write(destination_path / file_name)
# Out:
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.848818 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.848818 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.852381 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.852381 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.855958 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.855958 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.859533 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.859533 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.863088 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.863088 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.866649 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.866649 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.870202 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.870202 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.873761 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.873761 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.877346 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.877346 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.880911 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.880911 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.884470 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.884470 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.888038 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.888038 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.891605 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.891605 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.896717 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.896717 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.900265 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.900265 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.903834 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.903834 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.907401 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.907401 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.910965 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.910965 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.914594 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.914594 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.918192 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.918192 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.921778 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.921778 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.925338 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.925338 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.928894 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.928894 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.932477 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.932477 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.936039 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.936039 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.939602 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.939602 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.943197 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.943197 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.948240 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.948240 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.951822 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.951822 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.955405 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.955405 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.958966 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.958966 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.962517 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.962517 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.966071 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.966071 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.969634 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.969634 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.973212 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.973212 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.976772 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.976772 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.980367 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.980367 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.983938 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.983938 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.987489 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.987489 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.991055 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59920.991055 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.006088 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.006088 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.009702 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.009702 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.013262 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.013262 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.016831 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.016831 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.020412 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.020412 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.023995 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.023995 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.027575 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.027575 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.031149 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.031149 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.034717 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.034717 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.038289 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.038289 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.041873 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.041873 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.045456 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.045456 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.049034 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.049034 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.052622 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.052622 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.057578 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.057578 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.061129 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.061129 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.064700 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.064700 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.068263 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.068263 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.071819 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.071819 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.075398 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.075398 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.078966 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.078966 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.082551 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.082551 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.086122 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.086122 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.089684 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.089684 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.093253 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.093253 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.096806 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.096806 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.100376 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.100376 from DATE-OBS'.
# ...
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.103954 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.103954 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.111661 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.111661 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.115221 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.115221 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.118821 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.118821 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.122387 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.122387 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.125928 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.125928 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.129490 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.129490 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.133075 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.133075 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.136636 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.136636 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.140213 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.140213 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.143791 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.143791 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.147365 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.147365 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.150961 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.150961 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.154564 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.154564 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.158139 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.158139 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.165524 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.165524 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.169114 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.169114 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.172713 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.172713 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.176274 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.176274 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.179817 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.179817 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.183413 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.183413 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.187054 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.187054 from DATE-OBS'.
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: RADECSYS= 'FK5 ' / RADECSYS
# the RADECSYS keyword is deprecated, use RADESYSa.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.190694 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59921.190694 from DATE-OBS'.
