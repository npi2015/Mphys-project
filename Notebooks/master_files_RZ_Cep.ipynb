# %% [markdown]
# # Creating Master Files
#
# In this notebook we are going to be writing code to create a master BIAS, master darks and master flats for the observations of RV UMa. Before we get started, here is a brief explanation of what these files are and why they have to be reduced and treated.
#
# * What is a master dark/bias/flat image?
#
#     A master image is a combination of several raw images, averaged per pixel to reduce the noise. They are what is used since noise is random, and as such can be averaged out of this kind of images, which on paper have to be always the same. They then allow us to remove all of these effects from the science image, getting to an image of what we wanted to observe with no effects of the telescope messing with it.
#
# * What is a dark frame?
#
#     A dark frame is an image taken with the shutter on the telescope, and is used to account for dark current, which can lead to false positives in the photon count. Ideally, they have the same exposure as the science frames, but they can be scaled to different exposures if the bias is removed first.
#
# * What is a flat frame?
#
#     A flat frame is an image of the entire sky, uniformly lit, used to account for stuff in the telescope (like dust) that can get in the way of the science image. They are taken with a white t-shirt draped over the unfocused lens.
#
# * What is a bias frame?
#
#     A bias is an offset voltage applied so that all the voltages in the image are positive and as such can be digitalized (a negative voltage cannot be possibly converted into a number). A bias frame is an image with the shutter closed and the shortest possible exposure that gives us the value of this bias. Ideally, it should be constant, but that is often not the case.

# %% [markdown]
# ## Creating the master bias files
#
# We start by averaging the bias files to create a master bias. First, the imports.

# %%
from pathlib import Path
import os

from astropy.nddata import CCDData
from astropy.stats import mad_std

import ccdproc as ccdp
import matplotlib.pyplot as plt
import numpy as np

from convenience_functions import show_image

plt.style.use('guide.mplstyle')

# %% [markdown]
# We create a new directory to store our reduced images.

# %%
calibrated_data = Path('..', 'bias-reduced-RzCep')
calibrated_data.mkdir(exist_ok=True)

# %% [markdown]
# And this is the path to our raw bias images.

# %%
bias_files = Path('..', '2022_12_06', 'RZ_Cep', 'Bias') # = 2022_03_20/Bias
files = ccdp.ImageFileCollection(bias_files)

# %%
files.summary[:5]
# Out:
# <Table masked=True length=5>
#               file               ...
#              str32               ...
# -------------------------------- ...
# star_Bias_0.000032_secs_001.fits ...
# star_Bias_0.000032_secs_002.fits ...
# star_Bias_0.000032_secs_003.fits ...
# star_Bias_0.000032_secs_004.fits ...
# star_Bias_0.000032_secs_005.fits ...

# %% [markdown]
# ### Combining BIAS images to make a master
#
# We are using ccdproc to combine the images into a master. We are using the average to do so, but clipping according to the median to prevent outliers from skewing the image too much. If the file already exists it is pointless to run the code, so it has a check to prevent it from running if that is the case.

# %%
path_to_combined_bias = Path(calibrated_data, 'combined_bias.fit')
calibrated_biases = files.files_filtered(imagetyp='Bias Frame', include_path=True)
if path_to_combined_bias.is_file():
    print('File exists,no combination necessary')
    combined_bias = path_to_combined_bias
else:
    combined_bias = ccdp.combine(calibrated_biases,
                                 method='average',
                                 sigma_clip=True, sigma_clip_low_thresh=5, sigma_clip_high_thresh=5,
                                 sigma_clip_func=np.ma.median, signma_clip_dev_func=mad_std,
                                 mem_limit=350e6, unit = 'adu'
                                 )

    combined_bias.meta['combined'] = True
    combined_bias.write(calibrated_data / 'combined_bias.fit', overwrite = False)
# Out:
# WARNING: Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes. [astropy.io.fits.header]
# WARNING:astropy:Unexpected extra padding at the end of the file.  This padding may not be preserved when saving changes.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869690 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869690 from DATE-OBS'.
# INFO:astropy:splitting each image into 104 chunks to limit memory usage to 350000000.0 bytes.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869714 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869714 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869736 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869736 from DATE-OBS'.
# INFO: splitting each image into 104 chunks to limit memory usage to 350000000.0 bytes. [ccdproc.combiner]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869760 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869760 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869784 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869784 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869807 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869807 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869831 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869831 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869855 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869855 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869879 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869879 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869904 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869904 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869928 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869928 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869952 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869952 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869976 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.869976 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870000 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870000 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870025 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870025 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870049 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870049 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870072 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870072 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870094 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870094 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870118 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870118 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870141 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870141 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870163 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870163 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870186 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870186 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870209 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870209 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870233 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870233 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870256 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.870256 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.879286 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.879286 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.879309 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.879309 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.879360 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.879360 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.879480 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.879480 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.879633 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.879633 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.879664 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.879664 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.879806 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.879806 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.879958 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.879958 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.879981 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.879981 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.880136 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.880136 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.880289 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.880289 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.880312 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.880312 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.880463 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.880463 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.880602 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.880602 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.880637 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.880637 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.880789 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.880789 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.880905 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.880905 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.880961 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.880961 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.881113 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.881113 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.881206 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.881206 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.881285 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.881285 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.881437 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.881437 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.881509 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.881509 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.881611 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.881611 from DATE-OBS'.
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.881762 from DATE-OBS'. [astropy.wcs.wcs]
# WARNING:astropy:FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 59919.881762 from DATE-OBS'.

# %% [markdown]
# ### Showing the difference between a raw bias and the master

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))

show_image(CCDData.read(calibrated_biases[0], unit = 'adu').data, cmap='gray', ax=ax1, fig=fig)
ax1.set_title('Single calibrated bias')
show_image(CCDData.read(combined_bias), cmap='gray', ax=ax2, fig=fig)
ax2.set_title('{} bias images combined'.format(len(calibrated_biases)));
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [9], in <cell line: 5>()
#       3 show_image(CCDData.read(calibrated_biases[0], unit = 'adu').data, cmap='gray', ax=ax1, fig=fig)
#       4 ax1.set_title('Single calibrated bias')
# ----> 5 show_image(CCDData.read(combined_bias), cmap='gray', ax=ax2, fig=fig)
#       6 ax2.set_title('{} bias images combined'.format(len(calibrated_biases)))
#
# File ~\anaconda3\Lib\site-packages\astropy\nddata\mixins\ndio.py:59, in NDDataRead.__call__(self, *args, **kwargs)
#      58 def __call__(self, *args, **kwargs):
# ---> 59     return self.registry.read(self._cls, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\astropy\io\registry\core.py:208, in UnifiedInputRegistry.read(self, cls, format, cache, *args, **kwargs)
#     205             path = None
#     206             fileobj = args[0]
# --> 208     format = self._get_valid_format(
#     209         'read', cls, path, fileobj, args, kwargs)
#     211 reader = self.get_reader(format, cls)
#     212 data = reader(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\astropy\io\registry\base.py:333, in _UnifiedIORegistryBase._get_valid_format(self, mode, cls, path, fileobj, args, kwargs)
#     328 def _get_valid_format(self, mode, cls, path, fileobj, args, kwargs):
#     329     """
#     330     Returns the first valid format that can be used to read/write the data in
#     331     question.  Mode can be either 'read' or 'write'.
#     332     """
# --> 333     valid_formats = self.identify_format(mode, cls, path, fileobj, args, kwargs)
#     335     if len(valid_formats) == 0:
#     336         format_table_str = self._get_format_table_str(cls, mode.capitalize())
#
# File ~\anaconda3\Lib\site-packages\astropy\io\registry\base.py:293, in _UnifiedIORegistryBase.identify_format(self, origin, data_class_required, path, fileobj, args, kwargs)
#     291 for data_format, data_class in self._identifiers:
#     292     if self._is_best_match(data_class_required, data_class, self._identifiers):
# --> 293         if self._identifiers[(data_format, data_class)](
#     294                 origin, path, fileobj, *args, **kwargs):
#     295             valid_formats.append(data_format)
#     297 return valid_formats
#
# File ~\anaconda3\Lib\site-packages\astropy\io\fits\connect.py:53, in is_fits(origin, filepath, fileobj, *args, **kwargs)
#      39 """
#      40 Determine whether `origin` is a FITS file.
#      41
#    (...)
#      50     Returns `True` if the given file is a FITS file.
#      51 """
#      52 if fileobj is not None:
# ---> 53     pos = fileobj.tell()
#      54     sig = fileobj.read(30)
#      55     fileobj.seek(pos)
#
# AttributeError: 'CCDData' object has no attribute 'tell'

# %% [markdown]
# ## Combining darks by exposure time
# Since we have darks for the different exposure times we don't need to subtract the BIAS in the files, and no calibration is necessary.

# %%
from pathlib import Path
import os

from astropy.nddata import CCDData
from astropy.stats import mad_std

import ccdproc as ccdp
import matplotlib.pyplot as plt
import numpy as np

from convenience_functions import show_image

# %%
calibrated_darks_path = Path('..', 'darks-reduced-6-12-RzCep')
calibrated_darks_path.mkdir(exist_ok=True)

# %%
dark_files_path = Path('..', '2022_12_06', 'RZ_Cep', 'Dark')
dark_files = ccdp.ImageFileCollection(dark_files_path)

# %%
darks = dark_files.summary['imagetyp'] == 'Dark Frame'
dark_times = set(dark_files.summary['exptime'][darks])
print(dark_times)
# Out:
# {18.0, 5.0}

# %%
import warnings
from astropy.utils.exceptions import AstropyWarning
warnings.simplefilter('ignore', category=AstropyWarning)

# %%
for exp_time in sorted(dark_times):
    path_dark_file = Path(calibrated_darks_path, f'combined_dark_{exp_time}.fit')
    if path_dark_file.is_file():
        print(f'Master dark for {exp_time} already exists')
    else:
        calibrated_darks = dark_files.files_filtered(imagetyp='Dark Frame', exptime=exp_time,
                                                         include_path=True)

        combined_dark = ccdp.combine(calibrated_darks,
                                     method='average',
                                     sigma_clip=True, sigma_clip_low_thresh=5, sigma_clip_high_thresh=5,
                                     sigma_clip_func=np.ma.median, signma_clip_dev_func=mad_std,
                                     mem_limit=350e6, unit = 'adu', verbose = False
                                     )

        combined_dark.meta['combined'] = True

        dark_file_name = f'combined_dark_{exp_time}.fit'
        combined_dark.write(calibrated_darks_path / dark_file_name)
# Out:
# INFO:astropy:splitting each image into 104 chunks to limit memory usage to 350000000.0 bytes.
# INFO: splitting each image into 104 chunks to limit memory usage to 350000000.0 bytes. [ccdproc.combiner]
# INFO:astropy:splitting each image into 104 chunks to limit memory usage to 350000000.0 bytes.
# INFO: splitting each image into 104 chunks to limit memory usage to 350000000.0 bytes. [ccdproc.combiner]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))

show_image(CCDData.read(calibrated_darks[0], unit = 'adu').data, cmap='gray', ax=ax1, fig=fig)
ax1.set_title('Single calibrated dark')
show_image(combined_dark.data, cmap='gray', ax=ax2, fig=fig)
ax2.set_title('{} dark images combined'.format(len(calibrated_darks)))
# Out:
# Text(0.5, 1.0, '50 dark images combined')

# %% [markdown]
# ## Darks from day 2

# %%
calibrated_darks_path = Path('..', 'darks-reduced-7-12-RzCep')
calibrated_darks_path.mkdir(exist_ok=True)

# %%
dark_files_path = Path('..', '2022_12_07', 'Dark')
dark_files = ccdp.ImageFileCollection(dark_files_path)

# %%
darks = dark_files.summary['imagetyp'] == 'Dark Frame'
dark_times = set(dark_files.summary['exptime'][darks])
print(dark_times)
# Out:
# {0.0085, 0.034, 0.02}

# %%
for exp_time in sorted(dark_times):
    path_dark_file = Path(calibrated_darks_path, f'combined_dark_{exp_time}.fit')
    if path_dark_file.is_file():
        print(f'Master dark for {exp_time} already exists')
    else:
        calibrated_darks = dark_files.files_filtered(imagetyp='Dark Frame', exptime=exp_time,
                                                     include_path=True)

        combined_dark = ccdp.combine(calibrated_darks,
                                     method='average',
                                     sigma_clip=True, sigma_clip_low_thresh=5, sigma_clip_high_thresh=5,
                                     sigma_clip_func=np.ma.median, signma_clip_dev_func=mad_std,
                                     mem_limit=350e6, unit = 'adu', verbose = False
                                     )

        combined_dark.meta['combined'] = True

        dark_file_name = f'combined_dark_{exp_time}.fit'
        combined_dark.write(calibrated_darks_path / dark_file_name)
# Out:
# INFO:astropy:splitting each image into 104 chunks to limit memory usage to 350000000.0 bytes.
# INFO: splitting each image into 104 chunks to limit memory usage to 350000000.0 bytes. [ccdproc.combiner]
# INFO:astropy:splitting each image into 104 chunks to limit memory usage to 350000000.0 bytes.
# INFO: splitting each image into 104 chunks to limit memory usage to 350000000.0 bytes. [ccdproc.combiner]
# INFO:astropy:splitting each image into 104 chunks to limit memory usage to 350000000.0 bytes.
# INFO: splitting each image into 104 chunks to limit memory usage to 350000000.0 bytes. [ccdproc.combiner]

# %%
import warnings
from astropy.utils.exceptions import AstropyWarning
warnings.simplefilter('ignore', category=AstropyWarning)

# %% [markdown]
# # Combined Flats

# %%
def find_nearest_dark_exposure(image, dark_exposure_times, tolerance=0.5):
    """
    Find the nearest exposure time of a dark frame to the exposure time of the image,
    raising an error if the difference in exposure time is more than tolerance.

    Parameters
    ----------

    image : astropy.nddata.CCDData
        Image for which a matching dark is needed.

    dark_exposure_times : list
        Exposure times for which there are darks.

    tolerance : float or ``None``, optional
        Maximum difference, in seconds, between the image and the closest dark. Set
        to ``None`` to skip the tolerance test.

    Returns
    -------

    float
        Closest dark exposure time to the image.
    """

    dark_exposures = np.array(list(dark_exposure_times))
    idx = np.argmin(np.abs(dark_exposures - image.header['exptime']))
    closest_dark_exposure = dark_exposures[idx]

    if (tolerance is not None and
            np.abs(image.header['exptime'] - closest_dark_exposure) > tolerance):

        raise RuntimeError('Closest dark exposure time is {} for flat of exposure '
                           'time {}.'.format(closest_dark_exposure, image.header['exptime']))


    return closest_dark_exposure

# %%
from pathlib import Path

from astropy import units as u
from astropy.nddata import CCDData
import ccdproc as ccdp
from matplotlib import pyplot as plt
import numpy as np

from convenience_functions import show_image

# %%
filter_name = 'Red'

reduced_path = Path('..', 'darks-reduced-7-12-RzCep')
destination_path = Path('..', 'reduced-flats-6-12', filter_name)
destination_path.mkdir(exist_ok = True)

ifc_reduced = ccdp.ImageFileCollection(reduced_path)

combined_dark_files = ifc_reduced.files_filtered(imagetyp='Dark Frame', combined=True)

flat_image_type = 'FLATFIELD'

# %%
raw_data = Path('..', '2022_12_07', 'Flat', filter_name)

ifc_raw = ccdp.ImageFileCollection(raw_data)

# %%
a_flat = CCDData.read(ifc_raw.files_filtered(imagetyp='Flat Frame', include_path=True)[0], unit='adu')

show_image(a_flat, cmap='gray')

# %%
actual_exposure_times = set(h['exptime'] for h in ifc_reduced.headers(imagetyp='Dark Frame', combined=True))

# %%
closest_dark = find_nearest_dark_exposure(a_flat, actual_exposure_times)

# %%
combined_darks = {ccd.header['exptime']: ccd for ccd in ifc_reduced.ccds(imagetyp='Dark Frame', combined=True)}

# %%
a_flat_reduced = ccdp.subtract_dark(a_flat, combined_darks[closest_dark],
                                    exposure_time='exptime', exposure_unit=u.second, scale=False)
show_image(a_flat_reduced, cmap='gray')

# %%
for ccd, file_name in ifc_raw.ccds(imagetyp='Flat Frame',  # Just get the flat frames
                                   ccd_kwargs={'unit': 'adu'},  # CCDData requires a unit for the image if
                                   # it is not in the header
                                   return_fname=True  # Provide the file name too.
                                   ):
    path_flat_file = Path('..', 'reduced-flats', 'flat-'+file_name)
    if path_flat_file.is_file():
        print('File already exists')
    else:
        # Find the correct dark exposure
        closest_dark = find_nearest_dark_exposure(ccd, actual_exposure_times)

        # Subtract the dark current
        ccd = ccdp.subtract_dark(ccd, combined_darks[closest_dark],
                                 exposure_time='exptime', exposure_unit=u.second)

        # Save the result; there are some duplicate file names so pre-pend "flat"
        ccd.write(destination_path / ('flat-' + file_name))

# %% [markdown]
# # Combining Flats

# %%
calibrated_flat_path = Path('..', 'reduced-flats-6-12', filter_name)

flat_imagetyp = 'Flat Frame'

ifc = ccdp.ImageFileCollection(calibrated_flat_path)

# %%
flat_filters = set(h['filter'] for h in ifc.headers(imagetyp=flat_imagetyp))
flat_filters
# Out:
# {'Red'}

# %%
def inv_median(a):
    return 1 / np.median(a)

# %%
for filt in flat_filters:
    path_flat_file = Path(calibrated_flat_path, 'combined_flat_filter_{}.fit'.format(filt.replace("''", "p")))
    if path_flat_file.is_file():
        print(f'Master flat for filter {filt} already exists')
    else:
        to_combine = ifc.files_filtered(imagetyp=flat_imagetyp, filter=filt, include_path=True)
        combined_flat = ccdp.combine(to_combine,
                                     method='average', scale=inv_median,
                                     sigma_clip=True, sigma_clip_low_thresh=5, sigma_clip_high_thresh=5,
                                     sigma_clip_func=np.ma.median, signma_clip_dev_func=mad_std,
                                     mem_limit=350e6
                                     )

        combined_flat.meta['combined'] = True
        flat_file_name = 'combined_flat_filter_{}.fit'.format(filt.replace("''", "p"))
        combined_flat.write(calibrated_flat_path / flat_file_name)
# Out:
# INFO:astropy:splitting each image into 104 chunks to limit memory usage to 350000000.0 bytes.
# INFO: splitting each image into 104 chunks to limit memory usage to 350000000.0 bytes. [ccdproc.combiner]

# %%
ifc.refresh()
ifc.files_filtered(imagetyp=flat_imagetyp, combined=True)
# Out:
# array(['combined_flat_filter_Red.fit'], dtype='<U33')

# %%
show_image(combined_flat, cmap = 'gray')
